# %%
import numpy as np

mylist = [20,2,4,6,4,4,5,65,7,75,57]
print(mylist[1:3])
list2 = [2,3,4,5,5,3,45,54,55,55,55]
sum = [list2] + [mylist]
print(sum)
print(list2[2])
print(sum[1][2])
print(sum[0][2:4])
print(mylist[1:6:2])
s1 = np.array(mylist)
s2 = np.array( list2)
s3 = np.array(sum)
print(s3)
print(s1[0:5:-1])
print(s3)
print(s1+s2)
# Out:
# [2, 4]
# [[2, 3, 4, 5, 5, 3, 45, 54, 55, 55, 55], [20, 2, 4, 6, 4, 4, 5, 65, 7, 75, 57]]
# 4
# 4
# [4, 5]
# [2, 6, 4]
# [[ 2  3  4  5  5  3 45 54 55 55 55]
#  [20  2  4  6  4  4  5 65  7 75 57]]
# []
# [[ 2  3  4  5  5  3 45 54 55 55 55]
#  [20  2  4  6  4  4  5 65  7 75 57]]
# [ 22   5   8  11   9   7  50 119  62 130 112]
