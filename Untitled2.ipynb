# %% [markdown]
# <a href="https://colab.research.google.com/github/thakur698/Data-Science/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
def get_api_data():
  response = requests.get('https://jsonplaceholder.typicode.com/posts/1')
  if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame([data])
    display(df)
    print
    return data # Return the actual data

# %%
# Call the function to print the data
get_api_data()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# {'userId': 1,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#  'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
import requests

API_KEY = "67e4305a0768cedd06dcfaffb15e131d" # IMPORTANT: Replace "YOUR_API_KEY" with your actual OpenWeatherMap API key

city = "Delhi"

url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

response = requests.get(url)

data = response.json()

# Print full response
print(data)

# Check if the API call was successful before trying to extract data
if response.status_code == 200:
  # Extract useful data
  temperature = data["main"]["temp"]
  weather = data["weather"][0]["description"]
  humidity = data["main"]["humidity"]

  print(f"City: {city}")
  print(f"Temperature: {temperature}°C")
  print(f"Weather: {weather}")
  print(f"Humidity: {humidity}%")
else:
  print(f"Error fetching data: {data.get('message', 'Unknown error')}")
# Out:
# {'coord': {'lon': 77.2167, 'lat': 28.6667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 42.05, 'feels_like': 42.01, 'temp_min': 42.05, 'temp_max': 42.05, 'pressure': 998, 'humidity': 19, 'sea_level': 998, 'grnd_level': 973}, 'visibility': 6000, 'wind': {'speed': 4.12, 'deg': 300, 'gust': 9.26}, 'clouds': {'all': 0}, 'dt': 1779095947, 'sys': {'type': 1, 'id': 9165, 'country': 'IN', 'sunrise': 1779062337, 'sunset': 1779111383}, 'timezone': 19800, 'id': 1273294, 'name': 'Delhi', 'cod': 200}
# City: Delhi
# Temperature: 42.05°C
# Weather: clear sky
# Humidity: 19%
